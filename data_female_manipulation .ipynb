# %%
import pandas as pd
import matplotlib.pyplot as plt

df_female = pd.read_csv("data\population_female.csv", quotechar='"')
df_total = pd.read_csv("data\population_total.csv", quotechar='"')

# %%
df_diferencia = df_total[~df_total['Country Name'].isin(df_female['Country Name'])]
df_diferencia
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, Unnamed: 68]
# Index: []
#
# [0 rows x 69 columns]

# %%
df_female = df_female.drop(columns=["Country Code", "Indicator Name", "Indicator Code", "Unnamed: 68"])
df_female.set_index('Country Name', inplace=True)
df_female = df_female.T
df_female.index.name = "Years"
df_female.head()
# Out:
# Country Name  Aruba  Afghanistan   Angola  Albania  Andorra  \
# Years
# 1960          27927      4344798  2582555   798472     4692
# 1961          28252      4438399  2610936   823469     5035
# 1962          28628      4537295  2633066   848431     5394
# 1963          28975      4640784  2655756   873289     5766
# 1964          29285      4748904  2679307   898281     6144
#
# Country Name  United Arab Emirates  Argentina  Armenia  American Samoa  \
# Years
# 1960                         49431   10175528   958824            9627
# 1961                         51160   10357370   990539            9891
# 1962                         53032   10539647  1022504           10209
# 1963                         55050   10723652  1054591           10544
# 1964                         57170   10907254  1086630           10899
#
# Country Name  Antigua and Barbuda  ...  Virgin Islands (U.S.)  Viet Nam  \
# Years                              ...
# ...

# %%
df_female.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(10, 5))
for column in df_female.columns[:10]:
    plt.plot(df_female.index, df_female[column], label=column)


plt.title("Crecimiento de la población (1960-2023)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Poblation", fontsize=12)
plt.legend(title="Country")
plt.grid(True, linestyle="--", alpha=0.7)

plt.xticks(df_female.index[::10], rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x23bf2739750>,
# ...
#  [Text(0.0, 0, '1960'),
#   Text(10.0, 0, '1970'),
#   Text(20.0, 0, '1980'),
#   Text(30.0, 0, '1990'),
#   Text(40.0, 0, '2000'),
#   Text(50.0, 0, '2010'),
#   Text(60.0, 0, '2020')])
