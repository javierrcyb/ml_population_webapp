# %%
import pandas as pd
import matplotlib.pyplot as plt

df_total = pd.read_csv("data\population_total.csv", quotechar='"')

# %%
df_total = df_total.drop(columns=["Country Code", "Indicator Name", "Indicator Code", "Unnamed: 68"])
df_total.head()
# Out:
#   Country Name     1960     1961     1962     1963     1964      1965  \
# 0        Aruba    54922    55578    56320    57002    57619     58190
# 1  Afghanistan  9035043  9214083  9404406  9604487  9814318  10036008
# 2       Angola  5231654  5301583  5354310  5408320  5464187   5521981
# 3      Albania  1608800  1659800  1711319  1762621  1814135   1864791
# 4      Andorra     9510    10283    11086    11915    12764     13634
#
#        1966      1967      1968  ...        2014        2015        2016  \
# 0     58694     58990     59069  ...    106807.0    107906.0    108727.0
# 1  10266395  10505959  10756922  ...  32792523.0  33831764.0  34700612.0
# 2   5581386   5641807   5702699  ...  27160769.0  28157798.0  29183070.0
# 3   1914573   1965598   2022272  ...   2889104.0   2880703.0   2876101.0
# 4     14626     15837     17176  ...     73737.0     72174.0     72181.0
#
#          2017        2018      2019        2020      2021        2022  \
# ...

# %%
df_total.set_index('Country Name', inplace=True)
df_total = df_total.T

# %%
df_total.index.name = "Years"

# %%
df_total.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_total = df_total.drop(columns=["World"])

# %%
df_total
# Out:
# Country Name     Aruba  Afghanistan      Angola    Albania  Andorra  \
# Years
# 1960           54922.0    9035043.0   5231654.0  1608800.0   9510.0
# 1961           55578.0    9214083.0   5301583.0  1659800.0  10283.0
# 1962           56320.0    9404406.0   5354310.0  1711319.0  11086.0
# 1963           57002.0    9604487.0   5408320.0  1762621.0  11915.0
# 1964           57619.0    9814318.0   5464187.0  1814135.0  12764.0
# ...                ...          ...         ...        ...      ...
# 2019          109203.0   37856121.0  32375632.0  2854191.0  76474.0
# 2020          108587.0   39068979.0  33451132.0  2837849.0  77380.0
# 2021          107700.0   40000412.0  34532429.0  2811666.0  78364.0
# 2022          107310.0   40578842.0  35635029.0  2777689.0  79705.0
# 2023          107359.0   41454761.0  36749906.0  2745972.0  80856.0
#
# Country Name  United Arab Emirates   Argentina    Armenia  American Samoa  \
# Years
# ...

# %%
plt.figure(figsize=(10, 5))
for column in df_total.columns[:10]:
    plt.plot(df_total.index, df_total[column], label=column)


plt.title("Crecimiento de la población (1960-2023)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Poblation", fontsize=12)
plt.legend(title="Country")
plt.grid(True, linestyle="--", alpha=0.7)

plt.xticks(df_total.index[::10], rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x1d67b9630d0>,
# ...
#  [Text(0.0, 0, '1960'),
#   Text(10.0, 0, '1970'),
#   Text(20.0, 0, '1980'),
#   Text(30.0, 0, '1990'),
#   Text(40.0, 0, '2000'),
#   Text(50.0, 0, '2010'),
#   Text(60.0, 0, '2020')])
